# %%
# Dependências
from components import Network, Controller
from components.qkd.app import *
import numpy as np

# %%
# Definindo rede e controlador
rede = Network()
rede.set_topology("China")
controlador = Controller(rede)

# Algumas propriedades da rede
rede.neprs = 3
rede.set_fidelity(0.95)
rede.draw()

# %%
# Propriedades da simulação
apps = ["BB84", "E91", "B92"]
apps_distribution = [0.33, 0.33, 0.33]
routes_calculation_type = 'kshortest'
numero_qubits = [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000]
requests = 100
n_simulacoes = 10
caso = 5

# %%
# Executando simulações variando o número de qubits com k = 1
k = 1
for nqubits in numero_qubits:
    rede.set_nqubits(nqubits)
    vazao, taxa = run_simulations(rede, controlador, n_simulacoes, requests, apps, apps_distribution, caso, routes_calculation_type, k)
    media_vazao = np.mean(vazao)
    desvio_padrao_vazao = np.std(vazao)
    print(f'=SPLIT("{formatar_numero(media_vazao)} {formatar_numero(desvio_padrao_vazao)}"; " ")')
# Out:
# =SPLIT("1,9995403 0,1795264"; " ")
# =SPLIT("2,9856344 0,4175983"; " ")
# =SPLIT("4,7580285 0,5267926"; " ")
# =SPLIT("6,2191815 0,7249822"; " ")
# =SPLIT("6,9911657 0,5631594"; " ")
# =SPLIT("6,7863982 0,9596473"; " ")
# =SPLIT("7,0409678 0,7829912"; " ")
# =SPLIT("6,9789377 0,4881597"; " ")
# =SPLIT("6,7135585 0,5580439"; " ")
# =SPLIT("6,9789377 0,4881597"; " ")

# %%
# Executando simulações variando o número de qubits com k = 1
k = 2
for nqubits in numero_qubits:
    rede.set_nqubits(nqubits)
    vazao, taxa = run_simulations(rede, controlador, n_simulacoes, requests, apps, apps_distribution, caso, routes_calculation_type, k)
    media_vazao = np.mean(vazao)
    desvio_padrao_vazao = np.std(vazao)
    print(f'=SPLIT("{formatar_numero(media_vazao)} {formatar_numero(desvio_padrao_vazao)}"; " ")')
# Out:
# =SPLIT("1,9761412 0,1911517"; " ")
# =SPLIT("3,1772656 0,2684348"; " ")
# =SPLIT("4,9177299 0,4396739"; " ")
# =SPLIT("5,5523621 0,7163948"; " ")
# =SPLIT("7,3244990 0,7384174"; " ")
# =SPLIT("7,2197802 0,8593160"; " ")
# =SPLIT("6,7929519 0,9125213"; " ")
# =SPLIT("7,5231019 0,6823283"; " ")
# =SPLIT("7,5604396 0,5526039"; " ")
# =SPLIT("6,9656593 0,3828017"; " ")

# %%
# Executando simulações variando o número de qubits com k = 1
k = 3
for nqubits in numero_qubits:
    rede.set_nqubits(nqubits)
    vazao, taxa = run_simulations(rede, controlador, n_simulacoes, requests, apps, apps_distribution, caso, routes_calculation_type, k)
    media_vazao = np.mean(vazao)
    desvio_padrao_vazao = np.std(vazao)
    print(f'=SPLIT("{formatar_numero(media_vazao)} {formatar_numero(desvio_padrao_vazao)}"; " ")')
# Out:
# =SPLIT("2,0360886 0,3226836"; " ")
# =SPLIT("3,3179721 0,4966422"; " ")
# =SPLIT("5,2632312 0,6183731"; " ")
# =SPLIT("6,0192308 0,9120603"; " ")
# =SPLIT("7,0468918 0,8512322"; " ")
# =SPLIT("7,2146089 0,7160493"; " ")
# =SPLIT("6,8494128 0,8013639"; " ")
# =SPLIT("6,6199813 0,5008186"; " ")
# =SPLIT("7,2687729 0,7183138"; " ")
# =SPLIT("7,2811355 0,8006429"; " ")

# %%
# Executando simulações variando o número de qubits com k = 1
k = 4
for nqubits in numero_qubits:
    rede.set_nqubits(nqubits)
    vazao, taxa = run_simulations(rede, controlador, n_simulacoes, requests, apps, apps_distribution, caso, routes_calculation_type, k)
    media_vazao = np.mean(vazao)
    desvio_padrao_vazao = np.std(vazao)
    print(f'=SPLIT("{formatar_numero(media_vazao)} {formatar_numero(desvio_padrao_vazao)}"; " ")')
# Out:
# =SPLIT("2,0144772 0,2341870"; " ")
# =SPLIT("3,3331122 0,4437371"; " ")
# =SPLIT("4,9936997 0,4658839"; " ")
# =SPLIT("6,0201645 0,8141134"; " ")
# =SPLIT("7,2192611 0,9689588"; " ")
# =SPLIT("7,1102133 0,6934094"; " ")
# =SPLIT("7,1263736 0,5121955"; " ")
# =SPLIT("6,7358238 0,6732677"; " ")
# =SPLIT("7,2959957 0,8999490"; " ")
# =SPLIT("6,9159770 0,9171973"; " ")

# %%
# Executando simulações variando o número de qubits com k = 1
k = 5
for nqubits in numero_qubits:
    rede.set_nqubits(nqubits)
    vazao, taxa = run_simulations(rede, controlador, n_simulacoes, requests, apps, apps_distribution, caso, routes_calculation_type, k)
    media_vazao = np.mean(vazao)
    desvio_padrao_vazao = np.std(vazao)
    print(f'=SPLIT("{formatar_numero(media_vazao)} {formatar_numero(desvio_padrao_vazao)}"; " ")')
# Out:
# =SPLIT("2,0020565 0,1603964"; " ")
# =SPLIT("3,2491494 0,3904364"; " ")
# =SPLIT("4,6505234 0,7562130"; " ")
# =SPLIT("5,9429294 0,7452320"; " ")
# =SPLIT("6,9797009 0,9299666"; " ")
# =SPLIT("7,4786880 0,7530124"; " ")
# =SPLIT("7,0595238 0,7099072"; " ")
# =SPLIT("7,3761239 0,7860552"; " ")
# =SPLIT("7,2335899 0,8299044"; " ")
# =SPLIT("7,6677905 0,8317932"; " ")
